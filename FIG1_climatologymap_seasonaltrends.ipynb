# %% [markdown]
# Note: this is very bad data import, and not perfect
#
# *In development of improved way to handle this*

# %%
from netCDF4 import Dataset
import matplotlib.pyplot as plt
from mpl_toolkits.basemap import Basemap
import numpy as np
import cmocean as cmo
import pandas as pd
import csv
from matplotlib.gridspec import GridSpec
from scipy import stats, integrate

# %%
fwc_dir = '../DATA/EC-fwc/'
mdl_data = Dataset(fwc_dir + 'monthly_fwc_EC-Earth3_historical_r1_1950-2014.nc')
mdl_data2 = Dataset(fwc_dir + 'monthly_fwc_EC-Earth3_historical_r2_1950-2014.nc')
mdl_data3 = Dataset(fwc_dir + 'monthly_fwc_EC-Earth3_historical_r3_1950-2014.nc')
mdl_data4 = Dataset(fwc_dir + 'monthly_fwc_EC-Earth3_historical_r4_1950-2014.nc')
mdl_data6 = Dataset(fwc_dir + 'monthly_fwc_EC-Earth3_historical_r6_1950-2014.nc')
mdl_data7 = Dataset(fwc_dir + 'monthly_fwc_EC-Earth3_historical_r7_1950-2014.nc')
mdl_data9 = Dataset(fwc_dir + 'monthly_fwc_EC-Earth3_historical_r9_1950-2014.nc')
mdl_data10 = Dataset(fwc_dir + 'monthly_fwc_EC-Earth3_historical_r10_1950-2014.nc')
mdl_data11 = Dataset(fwc_dir + 'monthly_fwc_EC-Earth3_historical_r11_1950-2014.nc')
mdl_data12 = Dataset(fwc_dir + 'monthly_fwc_EC-Earth3_historical_r12_1950-2014.nc')
mdl_data13 = Dataset(fwc_dir + 'monthly_fwc_EC-Earth3_historical_r13_1950-2014.nc')
mdl_data14 = Dataset(fwc_dir + 'monthly_fwc_EC-Earth3_historical_r14_1950-2014.nc')
mdl_data15 = Dataset(fwc_dir + 'monthly_fwc_EC-Earth3_historical_r15_1950-2014.nc')
mdl_data16 = Dataset(fwc_dir + 'monthly_fwc_EC-Earth3_historical_r16_1950-2014.nc')
mdl_data17 = Dataset(fwc_dir + 'monthly_fwc_EC-Earth3_historical_r17_1950-2014.nc')
mdl_data18 = Dataset(fwc_dir + 'monthly_fwc_EC-Earth3_historical_r18_1950-2014.nc')
mdl_data19 = Dataset(fwc_dir + 'monthly_fwc_EC-Earth3_historical_r19_1950-2014.nc')
mdl_data21 = Dataset(fwc_dir + 'monthly_fwc_EC-Earth3_historical_r21_1950-2014.nc')
mdl_data22 = Dataset(fwc_dir + 'monthly_fwc_EC-Earth3_historical_r22_1950-2014.nc')
mdl_data23 = Dataset(fwc_dir + 'monthly_fwc_EC-Earth3_historical_r23_1950-2014.nc')
mdl_data24 = Dataset(fwc_dir + 'monthly_fwc_EC-Earth3_historical_r24_1950-2014.nc')
mdl_data25 = Dataset(fwc_dir + 'monthly_fwc_EC-Earth3_historical_r25_1950-2014.nc')

# %%
t = -420 # 12 months * 35 years
fwc1 = mdl_data.variables['fwc'][t:,:,:]
fwc2 = mdl_data2.variables['fwc'][t:,:,:]
fwc3 = mdl_data3.variables['fwc'][t:,:,:]
fwc4 = mdl_data4.variables['fwc'][t:,:,:]
fwc6 = mdl_data6.variables['fwc'][t:,:,:]
fwc7 = mdl_data7.variables['fwc'][t:,:,:]
fwc9 = mdl_data9.variables['fwc'][t:,:,:]
fwc10= mdl_data10.variables['fwc'][t:,:,:]
fwc11 = mdl_data11.variables['fwc'][t:,:,:]
fwc12 = mdl_data12.variables['fwc'][t:,:,:]
fwc13 = mdl_data13.variables['fwc'][t:,:,:]
fwc14 = mdl_data14.variables['fwc'][t:,:,:]
fwc15 = mdl_data15.variables['fwc'][t:,:,:]
fwc16 = mdl_data16.variables['fwc'][t:,:,:]
fwc17 = mdl_data17.variables['fwc'][t:,:,:]
fwc18 = mdl_data18.variables['fwc'][t:,:,:]
fwc19 = mdl_data19.variables['fwc'][t:,:,:]
fwc21 = mdl_data21.variables['fwc'][t:,:,:]
fwc22 = mdl_data22.variables['fwc'][t:,:,:]
fwc23 = mdl_data23.variables['fwc'][t:,:,:]
fwc24 = mdl_data24.variables['fwc'][t:,:,:]
fwc25 = mdl_data25.variables['fwc'][t:,:,:]

# %%
fwc1_m = np.ma.masked_where(fwc1 >= 100, fwc1)
fwc2_m = np.ma.masked_where(fwc2 >= 100, fwc2)
fwc3_m = np.ma.masked_where(fwc3 >= 100, fwc3)
fwc4_m = np.ma.masked_where(fwc4 >= 100, fwc4)
fwc6_m = np.ma.masked_where(fwc6 >= 100, fwc6)
fwc7_m = np.ma.masked_where(fwc7 >= 100, fwc7)
fwc9_m = np.ma.masked_where(fwc9 >= 100, fwc9)
fwc10_m = np.ma.masked_where(fwc10 >= 100, fwc10)
fwc11_m = np.ma.masked_where(fwc11 >= 100, fwc11)
fwc12_m = np.ma.masked_where(fwc12 >= 100, fwc12)
fwc13_m = np.ma.masked_where(fwc13 >= 100, fwc13)
fwc14_m = np.ma.masked_where(fwc14 >= 100, fwc14)
fwc15_m = np.ma.masked_where(fwc15 >= 100, fwc15)
fwc16_m = np.ma.masked_where(fwc16 >= 100, fwc16)
fwc17_m = np.ma.masked_where(fwc17 >= 100, fwc17)
fwc18_m = np.ma.masked_where(fwc18 >= 100, fwc18)
fwc19_m = np.ma.masked_where(fwc19 >= 100, fwc19)
fwc21_m = np.ma.masked_where(fwc21 >= 100, fwc21)
fwc22_m = np.ma.masked_where(fwc22 >= 100, fwc22)
fwc23_m = np.ma.masked_where(fwc23 >= 100, fwc23)
fwc24_m = np.ma.masked_where(fwc24 >= 100, fwc24)
fwc25_m = np.ma.masked_where(fwc25 >= 100, fwc25)

fwc1_m[:,:-24,:] = np.nan # bering
fwc1_m[:,:-10, -90:] = np.nan # fbso west
fwc1_m[:,:-10, :15] = np.nan # fbso east
fwc1_m[:,-30:-12, 180+53:360-45] = np.nan # caa

fwc2_m[:,:-24,:] = np.nan # bering
fwc2_m[:,:-10, -90:] = np.nan # fbso west
fwc2_m[:,:-10, :15] = np.nan # fbso east
fwc2_m[:,-30:-12, 180+53:360-45] = np.nan # caa

fwc3_m[:,:-24,:] = np.nan # bering
fwc3_m[:,:-10, -90:] = np.nan # fbso west
fwc3_m[:,:-10, :15] = np.nan # fbso east
fwc3_m[:,-30:-12, 180+53:360-45] = np.nan # caa

fwc4_m[:,:-24,:] = np.nan # bering
fwc4_m[:,:-10, -90:] = np.nan # fbso west
fwc4_m[:,:-10, :15] = np.nan # fbso east
fwc4_m[:,-30:-12, 180+53:360-45] = np.nan # caa

fwc6_m[:,:-24,:] = np.nan # bering
fwc6_m[:,:-10, -90:] = np.nan # fbso west
fwc6_m[:,:-10, :15] = np.nan # fbso east
fwc6_m[:,-30:-12, 180+53:360-45] = np.nan # caa

fwc7_m[:,:-24,:] = np.nan # bering
fwc7_m[:,:-10, -90:] = np.nan # fbso west
fwc7_m[:,:-10, :15] = np.nan # fbso east
fwc7_m[:,-30:-12, 180+53:360-45] = np.nan # caa

fwc9_m[:,:-24,:] = np.nan # bering
fwc9_m[:,:-10, -90:] = np.nan # fbso west
fwc9_m[:,:-10, :15] = np.nan # fbso east
fwc9_m[:,-30:-12, 180+53:360-45] = np.nan # caa

fwc10_m[:,:-24,:] = np.nan # bering
fwc10_m[:,:-10, -90:] = np.nan # fbso west
fwc10_m[:,:-10, :15] = np.nan # fbso east
fwc10_m[:,-30:-12, 180+53:360-45] = np.nan # caa

fwc11_m[:,:-24,:] = np.nan # bering
fwc11_m[:,:-10, -90:] = np.nan # fbso west
fwc11_m[:,:-10, :15] = np.nan # fbso east
fwc11_m[:,-30:-12, 180+53:360-45] = np.nan # caa

fwc12_m[:,:-24,:] = np.nan # bering
fwc12_m[:,:-10, -90:] = np.nan # fbso west
fwc12_m[:,:-10, :15] = np.nan # fbso east
fwc12_m[:,-30:-12, 180+53:360-45] = np.nan # caa

fwc13_m[:,:-24,:] = np.nan # bering
fwc13_m[:,:-10, -90:] = np.nan # fbso west
fwc13_m[:,:-10, :15] = np.nan # fbso east
fwc13_m[:,-30:-12, 180+53:360-45] = np.nan # caa

fwc14_m[:,:-24,:] = np.nan # bering
fwc14_m[:,:-10, -90:] = np.nan # fbso west
fwc14_m[:,:-10, :15] = np.nan # fbso east
fwc14_m[:,-30:-12, 180+53:360-45] = np.nan # caa

fwc15_m[:,:-24,:] = np.nan # bering
fwc15_m[:,:-10, -90:] = np.nan # fbso west
fwc15_m[:,:-10, :15] = np.nan # fbso east
fwc15_m[:,-30:-12, 180+53:360-45] = np.nan # caa

fwc16_m[:,:-24,:] = np.nan # bering
fwc16_m[:,:-10, -90:] = np.nan # fbso west
fwc16_m[:,:-10, :15] = np.nan # fbso east
fwc16_m[:,-30:-12, 180+53:360-45] = np.nan # caa

fwc17_m[:,:-24,:] = np.nan # bering
fwc17_m[:,:-10, -90:] = np.nan # fbso west
fwc17_m[:,:-10, :15] = np.nan # fbso east
fwc17_m[:,-30:-12, 180+53:360-45] = np.nan # caa

fwc18_m[:,:-24,:] = np.nan # bering
fwc18_m[:,:-10, -90:] = np.nan # fbso west
fwc18_m[:,:-10, :15] = np.nan # fbso east
fwc18_m[:,-30:-12, 180+53:360-45] = np.nan # caa

fwc19_m[:,:-24,:] = np.nan # bering
fwc19_m[:,:-10, -90:] = np.nan # fbso west
fwc19_m[:,:-10, :15] = np.nan # fbso east
fwc19_m[:,-30:-12, 180+53:360-45] = np.nan # caa

fwc21_m[:,:-24,:] = np.nan # bering
fwc21_m[:,:-10, -90:] = np.nan # fbso west
fwc21_m[:,:-10, :15] = np.nan # fbso east
fwc21_m[:,-30:-12, 180+53:360-45] = np.nan # caa

fwc22_m[:,:-24,:] = np.nan # bering
fwc22_m[:,:-10, -90:] = np.nan # fbso west
fwc22_m[:,:-10, :15] = np.nan # fbso east
fwc22_m[:,-30:-12, 180+53:360-45] = np.nan # caa

fwc23_m[:,:-24,:] = np.nan # bering
fwc23_m[:,:-10, -90:] = np.nan # fbso west
fwc23_m[:,:-10, :15] = np.nan # fbso east
fwc23_m[:,-30:-12, 180+53:360-45] = np.nan # caa

fwc24_m[:,:-24,:] = np.nan # bering
fwc24_m[:,:-10, -90:] = np.nan # fbso west
fwc24_m[:,:-10, :15] = np.nan # fbso east
fwc24_m[:,-30:-12, 180+53:360-45] = np.nan # caa

fwc25_m[:,:-24,:] = np.nan # bering
fwc25_m[:,:-10, -90:] = np.nan # fbso west
fwc25_m[:,:-10, :15] = np.nan # fbso east
fwc25_m[:,-30:-12, 180+53:360-45] = np.nan # caa

# %%
fwc_mon1 = fwc1_m[0::12,:,:]
fwc_mon2 = fwc1_m[1::12,:,:]
fwc_mon3 = fwc1_m[2::12,:,:]
fwc_mon4 = fwc1_m[3::12,:,:]
fwc_mon5 = fwc1_m[4::12,:,:]
fwc_mon6 = fwc1_m[5::12,:,:]
fwc_mon7 = fwc1_m[6::12,:,:]
fwc_mon8 = fwc1_m[7::12,:,:]
fwc_mon9 = fwc1_m[8::12,:,:]
fwc_mon10 = fwc1_m[9::12,:,:]
fwc_mon11 = fwc1_m[10::12,:,:]
fwc_mon12 = fwc1_m[11::12,:,:]
fwc_mon1_ts = np.nanmean(fwc_mon1, axis=(0,1,2))
fwc_mon2_ts = np.nanmean(fwc_mon2, axis=(0,1,2))
fwc_mon3_ts = np.nanmean(fwc_mon3, axis=(0,1,2))
fwc_mon4_ts = np.nanmean(fwc_mon4, axis=(0,1,2))
fwc_mon5_ts = np.nanmean(fwc_mon5, axis=(0,1,2))
fwc_mon6_ts = np.nanmean(fwc_mon6, axis=(0,1,2))
fwc_mon7_ts = np.nanmean(fwc_mon7, axis=(0,1,2))
fwc_mon8_ts = np.nanmean(fwc_mon8, axis=(0,1,2))
fwc_mon9_ts = np.nanmean(fwc_mon9, axis=(0,1,2))
fwc_mon10_ts = np.nanmean(fwc_mon10, axis=(0,1,2))
fwc_mon11_ts = np.nanmean(fwc_mon11, axis=(0,1,2))
fwc_mon12_ts = np.nanmean(fwc_mon12, axis=(0,1,2))

fwc2_mon1 = fwc2_m[0::12]
fwc2_mon2 = fwc2_m[1::12]
fwc2_mon3 = fwc2_m[2::12]
fwc2_mon4 = fwc2_m[3::12]
fwc2_mon5 = fwc2_m[4::12]
fwc2_mon6 = fwc2_m[5::12]
fwc2_mon7 = fwc2_m[6::12]
fwc2_mon8 = fwc2_m[7::12]
fwc2_mon9 = fwc2_m[8::12]
fwc2_mon10 = fwc2_m[9::12]
fwc2_mon11 = fwc2_m[10::12]
fwc2_mon12 = fwc2_m[11::12]
fwc2_mon1_ts = np.nanmean(fwc2_mon1, axis=(0,1,2))
fwc2_mon2_ts = np.nanmean(fwc2_mon2, axis=(0,1,2))
fwc2_mon3_ts = np.nanmean(fwc2_mon3, axis=(0,1,2))
fwc2_mon4_ts = np.nanmean(fwc2_mon4, axis=(0,1,2))
fwc2_mon5_ts = np.nanmean(fwc2_mon5, axis=(0,1,2))
fwc2_mon6_ts = np.nanmean(fwc2_mon6, axis=(0,1,2))
fwc2_mon7_ts = np.nanmean(fwc2_mon7, axis=(0,1,2))
fwc2_mon8_ts = np.nanmean(fwc2_mon8, axis=(0,1,2))
fwc2_mon9_ts = np.nanmean(fwc2_mon9, axis=(0,1,2))
fwc2_mon10_ts = np.nanmean(fwc2_mon10, axis=(0,1,2))
fwc2_mon11_ts = np.nanmean(fwc2_mon11, axis=(0,1,2))
fwc2_mon12_ts = np.nanmean(fwc2_mon12, axis=(0,1,2))

fwc3_mon1 = fwc3_m[0::12]
fwc3_mon2 = fwc3_m[1::12]
fwc3_mon3 = fwc3_m[2::12]
fwc3_mon4 = fwc3_m[3::12]
fwc3_mon5 = fwc3_m[4::12]
fwc3_mon6 = fwc3_m[5::12]
fwc3_mon7 = fwc3_m[6::12]
fwc3_mon8 = fwc3_m[7::12]
fwc3_mon9 = fwc3_m[8::12]
fwc3_mon10 = fwc3_m[9::12]
fwc3_mon11 = fwc3_m[10::12]
fwc3_mon12 = fwc3_m[11::12]
fwc3_mon1_ts = np.nanmean(fwc3_mon1, axis=(0,1,2))
fwc3_mon2_ts = np.nanmean(fwc3_mon2, axis=(0,1,2))
fwc3_mon3_ts = np.nanmean(fwc3_mon3, axis=(0,1,2))
fwc3_mon4_ts = np.nanmean(fwc3_mon4, axis=(0,1,2))
fwc3_mon5_ts = np.nanmean(fwc3_mon5, axis=(0,1,2))
fwc3_mon6_ts = np.nanmean(fwc3_mon6, axis=(0,1,2))
fwc3_mon7_ts = np.nanmean(fwc3_mon7, axis=(0,1,2))
fwc3_mon8_ts = np.nanmean(fwc3_mon8, axis=(0,1,2))
fwc3_mon9_ts = np.nanmean(fwc3_mon9, axis=(0,1,2))
fwc3_mon10_ts = np.nanmean(fwc3_mon10, axis=(0,1,2))
fwc3_mon11_ts = np.nanmean(fwc3_mon11, axis=(0,1,2))
fwc3_mon12_ts = np.nanmean(fwc3_mon12, axis=(0,1,2))

fwc4_mon1 = fwc4_m[0::12]
fwc4_mon2 = fwc4_m[1::12]
fwc4_mon3 = fwc4_m[2::12]
fwc4_mon4 = fwc4_m[3::12]
fwc4_mon5 = fwc4_m[4::12]
fwc4_mon6 = fwc4_m[5::12]
fwc4_mon7 = fwc4_m[6::12]
fwc4_mon8 = fwc4_m[7::12]
fwc4_mon9 = fwc4_m[8::12]
fwc4_mon10 = fwc4_m[9::12]
fwc4_mon11 = fwc4_m[10::12]
fwc4_mon12 = fwc4_m[11::12]
fwc4_mon1_ts = np.nanmean(fwc4_mon1, axis=(0,1,2))
fwc4_mon2_ts = np.nanmean(fwc4_mon2, axis=(0,1,2))
fwc4_mon3_ts = np.nanmean(fwc4_mon3, axis=(0,1,2))
fwc4_mon4_ts = np.nanmean(fwc4_mon4, axis=(0,1,2))
fwc4_mon5_ts = np.nanmean(fwc4_mon5, axis=(0,1,2))
fwc4_mon6_ts = np.nanmean(fwc4_mon6, axis=(0,1,2))
fwc4_mon7_ts = np.nanmean(fwc4_mon7, axis=(0,1,2))
fwc4_mon8_ts = np.nanmean(fwc4_mon8, axis=(0,1,2))
fwc4_mon9_ts = np.nanmean(fwc4_mon9, axis=(0,1,2))
fwc4_mon10_ts = np.nanmean(fwc4_mon10, axis=(0,1,2))
fwc4_mon11_ts = np.nanmean(fwc4_mon11, axis=(0,1,2))
fwc4_mon12_ts = np.nanmean(fwc4_mon12, axis=(0,1,2))

fwc6_mon1 = fwc6_m[0::12]
fwc6_mon2 = fwc6_m[1::12]
fwc6_mon3 = fwc6_m[2::12]
fwc6_mon4 = fwc6_m[3::12]
fwc6_mon5 = fwc6_m[4::12]
fwc6_mon6 = fwc6_m[5::12]
fwc6_mon7 = fwc6_m[6::12]
fwc6_mon8 = fwc6_m[7::12]
fwc6_mon9 = fwc6_m[8::12]
fwc6_mon10 = fwc6_m[9::12]
fwc6_mon11 = fwc6_m[10::12]
fwc6_mon12 = fwc6_m[11::12]
fwc6_mon1_ts = np.nanmean(fwc6_mon1, axis=(0,1,2))
fwc6_mon2_ts = np.nanmean(fwc6_mon2, axis=(0,1,2))
fwc6_mon3_ts = np.nanmean(fwc6_mon3, axis=(0,1,2))
fwc6_mon4_ts = np.nanmean(fwc6_mon4, axis=(0,1,2))
fwc6_mon5_ts = np.nanmean(fwc6_mon5, axis=(0,1,2))
fwc6_mon6_ts = np.nanmean(fwc6_mon6, axis=(0,1,2))
fwc6_mon7_ts = np.nanmean(fwc6_mon7, axis=(0,1,2))
fwc6_mon8_ts = np.nanmean(fwc6_mon8, axis=(0,1,2))
fwc6_mon9_ts = np.nanmean(fwc6_mon9, axis=(0,1,2))
fwc6_mon10_ts = np.nanmean(fwc6_mon10, axis=(0,1,2))
fwc6_mon11_ts = np.nanmean(fwc6_mon11, axis=(0,1,2))
fwc6_mon12_ts = np.nanmean(fwc6_mon12, axis=(0,1,2))

fwc7_mon1 = fwc7_m[0::12]
fwc7_mon2 = fwc7_m[1::12]
fwc7_mon3 = fwc7_m[2::12]
fwc7_mon4 = fwc7_m[3::12]
fwc7_mon5 = fwc7_m[4::12]
fwc7_mon6 = fwc7_m[5::12]
fwc7_mon7 = fwc7_m[6::12]
fwc7_mon8 = fwc7_m[7::12]
fwc7_mon9 = fwc7_m[8::12]
fwc7_mon10 = fwc7_m[9::12]
fwc7_mon11 = fwc7_m[10::12]
fwc7_mon12 = fwc7_m[11::12]
fwc7_mon1_ts = np.nanmean(fwc7_mon1, axis=(0,1,2))
fwc7_mon2_ts = np.nanmean(fwc7_mon2, axis=(0,1,2))
fwc7_mon3_ts = np.nanmean(fwc7_mon3, axis=(0,1,2))
fwc7_mon4_ts = np.nanmean(fwc7_mon4, axis=(0,1,2))
fwc7_mon5_ts = np.nanmean(fwc7_mon5, axis=(0,1,2))
fwc7_mon6_ts = np.nanmean(fwc7_mon6, axis=(0,1,2))
fwc7_mon7_ts = np.nanmean(fwc7_mon7, axis=(0,1,2))
fwc7_mon8_ts = np.nanmean(fwc7_mon8, axis=(0,1,2))
fwc7_mon9_ts = np.nanmean(fwc7_mon9, axis=(0,1,2))
fwc7_mon10_ts = np.nanmean(fwc7_mon10, axis=(0,1,2))
fwc7_mon11_ts = np.nanmean(fwc7_mon11, axis=(0,1,2))
fwc7_mon12_ts = np.nanmean(fwc7_mon12, axis=(0,1,2))

fwc9_mon1 = fwc9_m[0::12]
fwc9_mon2 = fwc9_m[1::12]
fwc9_mon3 = fwc9_m[2::12]
fwc9_mon4 = fwc9_m[3::12]
fwc9_mon5 = fwc9_m[4::12]
fwc9_mon6 = fwc9_m[5::12]
fwc9_mon7 = fwc9_m[6::12]
fwc9_mon8 = fwc9_m[7::12]
fwc9_mon9 = fwc9_m[8::12]
fwc9_mon10 = fwc9_m[9::12]
fwc9_mon11 = fwc9_m[10::12]
fwc9_mon12 = fwc9_m[11::12]
fwc9_mon1_ts = np.nanmean(fwc9_mon1, axis=(0,1,2))
fwc9_mon2_ts = np.nanmean(fwc9_mon2, axis=(0,1,2))
fwc9_mon3_ts = np.nanmean(fwc9_mon3, axis=(0,1,2))
fwc9_mon4_ts = np.nanmean(fwc9_mon4, axis=(0,1,2))
fwc9_mon5_ts = np.nanmean(fwc9_mon5, axis=(0,1,2))
fwc9_mon6_ts = np.nanmean(fwc9_mon6, axis=(0,1,2))
fwc9_mon7_ts = np.nanmean(fwc9_mon7, axis=(0,1,2))
fwc9_mon8_ts = np.nanmean(fwc9_mon8, axis=(0,1,2))
fwc9_mon9_ts = np.nanmean(fwc9_mon9, axis=(0,1,2))
fwc9_mon10_ts = np.nanmean(fwc9_mon10, axis=(0,1,2))
fwc9_mon11_ts = np.nanmean(fwc9_mon11, axis=(0,1,2))
fwc9_mon12_ts = np.nanmean(fwc9_mon12, axis=(0,1,2))

fwc10_mon1 = fwc10_m[0::12]
fwc10_mon2 = fwc10_m[1::12]
fwc10_mon3 = fwc10_m[2::12]
fwc10_mon4 = fwc10_m[3::12]
fwc10_mon5 = fwc10_m[4::12]
fwc10_mon6 = fwc10_m[5::12]
fwc10_mon7 = fwc10_m[6::12]
fwc10_mon8 = fwc10_m[7::12]
fwc10_mon9 = fwc10_m[8::12]
fwc10_mon10 = fwc10_m[9::12]
fwc10_mon11 = fwc10_m[10::12]
fwc10_mon12 = fwc10_m[11::12]
fwc10_mon1_ts = np.nanmean(fwc10_mon1, axis=(0,1,2))
fwc10_mon2_ts = np.nanmean(fwc10_mon2, axis=(0,1,2))
fwc10_mon3_ts = np.nanmean(fwc10_mon3, axis=(0,1,2))
fwc10_mon4_ts = np.nanmean(fwc10_mon4, axis=(0,1,2))
fwc10_mon5_ts = np.nanmean(fwc10_mon5, axis=(0,1,2))
fwc10_mon6_ts = np.nanmean(fwc10_mon6, axis=(0,1,2))
fwc10_mon7_ts = np.nanmean(fwc10_mon7, axis=(0,1,2))
fwc10_mon8_ts = np.nanmean(fwc10_mon8, axis=(0,1,2))
fwc10_mon9_ts = np.nanmean(fwc10_mon9, axis=(0,1,2))
fwc10_mon10_ts = np.nanmean(fwc10_mon10, axis=(0,1,2))
fwc10_mon11_ts = np.nanmean(fwc10_mon11, axis=(0,1,2))
fwc10_mon12_ts = np.nanmean(fwc10_mon12, axis=(0,1,2))


fwc11_mon1 = fwc11_m[0::12]
fwc11_mon2 = fwc11_m[1::12]
fwc11_mon3 = fwc11_m[2::12]
fwc11_mon4 = fwc11_m[3::12]
fwc11_mon5 = fwc11_m[4::12]
fwc11_mon6 = fwc11_m[5::12]
fwc11_mon7 = fwc11_m[6::12]
fwc11_mon8 = fwc11_m[7::12]
fwc11_mon9 = fwc11_m[8::12]
fwc11_mon10 = fwc11_m[9::12]
fwc11_mon11 = fwc11_m[10::12]
fwc11_mon12 = fwc11_m[11::12]
fwc11_mon1_ts = np.nanmean(fwc11_mon1, axis=(0,1,2))
fwc11_mon2_ts = np.nanmean(fwc11_mon2, axis=(0,1,2))
fwc11_mon3_ts = np.nanmean(fwc11_mon3, axis=(0,1,2))
fwc11_mon4_ts = np.nanmean(fwc11_mon4, axis=(0,1,2))
fwc11_mon5_ts = np.nanmean(fwc11_mon5, axis=(0,1,2))
fwc11_mon6_ts = np.nanmean(fwc11_mon6, axis=(0,1,2))
fwc11_mon7_ts = np.nanmean(fwc11_mon7, axis=(0,1,2))
fwc11_mon8_ts = np.nanmean(fwc11_mon8, axis=(0,1,2))
fwc11_mon9_ts = np.nanmean(fwc11_mon9, axis=(0,1,2))
fwc11_mon10_ts = np.nanmean(fwc11_mon10, axis=(0,1,2))
fwc11_mon11_ts = np.nanmean(fwc11_mon11, axis=(0,1,2))
fwc11_mon12_ts = np.nanmean(fwc11_mon12, axis=(0,1,2))

fwc12_mon1 = fwc12_m[0::12]
fwc12_mon2 = fwc12_m[1::12]
fwc12_mon3 = fwc12_m[2::12]
fwc12_mon4 = fwc12_m[3::12]
fwc12_mon5 = fwc12_m[4::12]
fwc12_mon6 = fwc12_m[5::12]
fwc12_mon7 = fwc12_m[6::12]
fwc12_mon8 = fwc12_m[7::12]
fwc12_mon9 = fwc12_m[8::12]
fwc12_mon10 = fwc12_m[9::12]
fwc12_mon11 = fwc12_m[10::12]
fwc12_mon12 = fwc12_m[11::12]
fwc12_mon1_ts = np.nanmean(fwc12_mon1, axis=(0,1,2))
fwc12_mon2_ts = np.nanmean(fwc12_mon2, axis=(0,1,2))
fwc12_mon3_ts = np.nanmean(fwc12_mon3, axis=(0,1,2))
fwc12_mon4_ts = np.nanmean(fwc12_mon4, axis=(0,1,2))
fwc12_mon5_ts = np.nanmean(fwc12_mon5, axis=(0,1,2))
fwc12_mon6_ts = np.nanmean(fwc12_mon6, axis=(0,1,2))
fwc12_mon7_ts = np.nanmean(fwc12_mon7, axis=(0,1,2))
fwc12_mon8_ts = np.nanmean(fwc12_mon8, axis=(0,1,2))
fwc12_mon9_ts = np.nanmean(fwc12_mon9, axis=(0,1,2))
fwc12_mon10_ts = np.nanmean(fwc12_mon10, axis=(0,1,2))
fwc12_mon11_ts = np.nanmean(fwc12_mon11, axis=(0,1,2))
fwc12_mon12_ts = np.nanmean(fwc12_mon12, axis=(0,1,2))

fwc13_mon1 = fwc13_m[0::12]
fwc13_mon2 = fwc13_m[1::12]
fwc13_mon3 = fwc13_m[2::12]
fwc13_mon4 = fwc13_m[3::12]
fwc13_mon5 = fwc13_m[4::12]
fwc13_mon6 = fwc13_m[5::12]
fwc13_mon7 = fwc13_m[6::12]
fwc13_mon8 = fwc13_m[7::12]
fwc13_mon9 = fwc13_m[8::12]
fwc13_mon10 = fwc13_m[9::12]
fwc13_mon11 = fwc13_m[10::12]
fwc13_mon12 = fwc13_m[11::12]
fwc13_mon1_ts = np.nanmean(fwc13_mon1, axis=(0,1,2))
fwc13_mon2_ts = np.nanmean(fwc13_mon2, axis=(0,1,2))
fwc13_mon3_ts = np.nanmean(fwc13_mon3, axis=(0,1,2))
fwc13_mon4_ts = np.nanmean(fwc13_mon4, axis=(0,1,2))
fwc13_mon5_ts = np.nanmean(fwc13_mon5, axis=(0,1,2))
fwc13_mon6_ts = np.nanmean(fwc13_mon6, axis=(0,1,2))
fwc13_mon7_ts = np.nanmean(fwc13_mon7, axis=(0,1,2))
fwc13_mon8_ts = np.nanmean(fwc13_mon8, axis=(0,1,2))
fwc13_mon9_ts = np.nanmean(fwc13_mon9, axis=(0,1,2))
fwc13_mon10_ts = np.nanmean(fwc13_mon10, axis=(0,1,2))
fwc13_mon11_ts = np.nanmean(fwc13_mon11, axis=(0,1,2))
fwc13_mon12_ts = np.nanmean(fwc13_mon12, axis=(0,1,2))

fwc14_mon1 = fwc14_m[0::12]
fwc14_mon2 = fwc14_m[1::12]
fwc14_mon3 = fwc14_m[2::12]
fwc14_mon4 = fwc14_m[3::12]
fwc14_mon5 = fwc14_m[4::12]
fwc14_mon6 = fwc14_m[5::12]
fwc14_mon7 = fwc14_m[6::12]
fwc14_mon8 = fwc14_m[7::12]
fwc14_mon9 = fwc14_m[8::12]
fwc14_mon10 = fwc14_m[9::12]
fwc14_mon11 = fwc14_m[10::12]
fwc14_mon12 = fwc14_m[11::12]
fwc14_mon1_ts = np.nanmean(fwc14_mon1, axis=(0,1,2))
fwc14_mon2_ts = np.nanmean(fwc14_mon2, axis=(0,1,2))
fwc14_mon3_ts = np.nanmean(fwc14_mon3, axis=(0,1,2))
fwc14_mon4_ts = np.nanmean(fwc14_mon4, axis=(0,1,2))
fwc14_mon5_ts = np.nanmean(fwc14_mon5, axis=(0,1,2))
fwc14_mon6_ts = np.nanmean(fwc14_mon6, axis=(0,1,2))
fwc14_mon7_ts = np.nanmean(fwc14_mon7, axis=(0,1,2))
fwc14_mon8_ts = np.nanmean(fwc14_mon8, axis=(0,1,2))
fwc14_mon9_ts = np.nanmean(fwc14_mon9, axis=(0,1,2))
fwc14_mon10_ts = np.nanmean(fwc14_mon10, axis=(0,1,2))
fwc14_mon11_ts = np.nanmean(fwc14_mon11, axis=(0,1,2))
fwc14_mon12_ts = np.nanmean(fwc14_mon12, axis=(0,1,2))

fwc15_mon1 = fwc15_m[0::12]
fwc15_mon2 = fwc15_m[1::12]
fwc15_mon3 = fwc15_m[2::12]
fwc15_mon4 = fwc15_m[3::12]
fwc15_mon5 = fwc15_m[4::12]
fwc15_mon6 = fwc15_m[5::12]
fwc15_mon7 = fwc15_m[6::12]
fwc15_mon8 = fwc15_m[7::12]
fwc15_mon9 = fwc15_m[8::12]
fwc15_mon10 = fwc15_m[9::12]
fwc15_mon11 = fwc15_m[10::12]
fwc15_mon12 = fwc15_m[11::12]
fwc15_mon1_ts = np.nanmean(fwc15_mon1, axis=(0,1,2))
fwc15_mon2_ts = np.nanmean(fwc15_mon2, axis=(0,1,2))
fwc15_mon3_ts = np.nanmean(fwc15_mon3, axis=(0,1,2))
fwc15_mon4_ts = np.nanmean(fwc15_mon4, axis=(0,1,2))
fwc15_mon5_ts = np.nanmean(fwc15_mon5, axis=(0,1,2))
fwc15_mon6_ts = np.nanmean(fwc15_mon6, axis=(0,1,2))
fwc15_mon7_ts = np.nanmean(fwc15_mon7, axis=(0,1,2))
fwc15_mon8_ts = np.nanmean(fwc15_mon8, axis=(0,1,2))
fwc15_mon9_ts = np.nanmean(fwc15_mon9, axis=(0,1,2))
fwc15_mon10_ts = np.nanmean(fwc15_mon10, axis=(0,1,2))
fwc15_mon11_ts = np.nanmean(fwc15_mon11, axis=(0,1,2))
fwc15_mon12_ts = np.nanmean(fwc15_mon12, axis=(0,1,2))

fwc16_mon1 = fwc16_m[0::12]
fwc16_mon2 = fwc16_m[1::12]
fwc16_mon3 = fwc16_m[2::12]
fwc16_mon4 = fwc16_m[3::12]
fwc16_mon5 = fwc16_m[4::12]
fwc16_mon6 = fwc16_m[5::12]
fwc16_mon7 = fwc16_m[6::12]
fwc16_mon8 = fwc16_m[7::12]
fwc16_mon9 = fwc16_m[8::12]
fwc16_mon10 = fwc16_m[9::12]
fwc16_mon11 = fwc16_m[10::12]
fwc16_mon12 = fwc16_m[11::12]
fwc16_mon1_ts = np.nanmean(fwc16_mon1, axis=(0,1,2))
fwc16_mon2_ts = np.nanmean(fwc16_mon2, axis=(0,1,2))
fwc16_mon3_ts = np.nanmean(fwc16_mon3, axis=(0,1,2))
fwc16_mon4_ts = np.nanmean(fwc16_mon4, axis=(0,1,2))
fwc16_mon5_ts = np.nanmean(fwc16_mon5, axis=(0,1,2))
fwc16_mon6_ts = np.nanmean(fwc16_mon6, axis=(0,1,2))
fwc16_mon7_ts = np.nanmean(fwc16_mon7, axis=(0,1,2))
fwc16_mon8_ts = np.nanmean(fwc16_mon8, axis=(0,1,2))
fwc16_mon9_ts = np.nanmean(fwc16_mon9, axis=(0,1,2))
fwc16_mon10_ts = np.nanmean(fwc16_mon10, axis=(0,1,2))
fwc16_mon11_ts = np.nanmean(fwc16_mon11, axis=(0,1,2))
fwc16_mon12_ts = np.nanmean(fwc16_mon12, axis=(0,1,2))

fwc17_mon1 = fwc17_m[0::12]
fwc17_mon2 = fwc17_m[1::12]
fwc17_mon3 = fwc17_m[2::12]
fwc17_mon4 = fwc17_m[3::12]
fwc17_mon5 = fwc17_m[4::12]
fwc17_mon6 = fwc17_m[5::12]
fwc17_mon7 = fwc17_m[6::12]
fwc17_mon8 = fwc17_m[7::12]
fwc17_mon9 = fwc17_m[8::12]
fwc17_mon10 = fwc17_m[9::12]
fwc17_mon11 = fwc17_m[10::12]
fwc17_mon12 = fwc17_m[11::12]
fwc17_mon1_ts = np.nanmean(fwc17_mon1, axis=(0,1,2))
fwc17_mon2_ts = np.nanmean(fwc17_mon2, axis=(0,1,2))
fwc17_mon3_ts = np.nanmean(fwc17_mon3, axis=(0,1,2))
fwc17_mon4_ts = np.nanmean(fwc17_mon4, axis=(0,1,2))
fwc17_mon5_ts = np.nanmean(fwc17_mon5, axis=(0,1,2))
fwc17_mon6_ts = np.nanmean(fwc17_mon6, axis=(0,1,2))
fwc17_mon7_ts = np.nanmean(fwc17_mon7, axis=(0,1,2))
fwc17_mon8_ts = np.nanmean(fwc17_mon8, axis=(0,1,2))
fwc17_mon9_ts = np.nanmean(fwc17_mon9, axis=(0,1,2))
fwc17_mon10_ts = np.nanmean(fwc17_mon10, axis=(0,1,2))
fwc17_mon11_ts = np.nanmean(fwc17_mon11, axis=(0,1,2))
fwc17_mon12_ts = np.nanmean(fwc17_mon12, axis=(0,1,2))

fwc18_mon1 = fwc18_m[0::12]
fwc18_mon2 = fwc18_m[1::12]
fwc18_mon3 = fwc18_m[2::12]
fwc18_mon4 = fwc18_m[3::12]
fwc18_mon5 = fwc18_m[4::12]
fwc18_mon6 = fwc18_m[5::12]
fwc18_mon7 = fwc18_m[6::12]
fwc18_mon8 = fwc18_m[7::12]
fwc18_mon9 = fwc18_m[8::12]
fwc18_mon10 = fwc18_m[9::12]
fwc18_mon11 = fwc18_m[10::12]
fwc18_mon12 = fwc18_m[11::12]
fwc18_mon1_ts = np.nanmean(fwc18_mon1, axis=(0,1,2))
fwc18_mon2_ts = np.nanmean(fwc18_mon2, axis=(0,1,2))
fwc18_mon3_ts = np.nanmean(fwc18_mon3, axis=(0,1,2))
fwc18_mon4_ts = np.nanmean(fwc18_mon4, axis=(0,1,2))
fwc18_mon5_ts = np.nanmean(fwc18_mon5, axis=(0,1,2))
fwc18_mon6_ts = np.nanmean(fwc18_mon6, axis=(0,1,2))
fwc18_mon7_ts = np.nanmean(fwc18_mon7, axis=(0,1,2))
fwc18_mon8_ts = np.nanmean(fwc18_mon8, axis=(0,1,2))
fwc18_mon9_ts = np.nanmean(fwc18_mon9, axis=(0,1,2))
fwc18_mon10_ts = np.nanmean(fwc18_mon10, axis=(0,1,2))
fwc18_mon11_ts = np.nanmean(fwc18_mon11, axis=(0,1,2))
fwc18_mon12_ts = np.nanmean(fwc18_mon12, axis=(0,1,2))


fwc19_mon1 = fwc19_m[0::12]
fwc19_mon2 = fwc19_m[1::12]
fwc19_mon3 = fwc19_m[2::12]
fwc19_mon4 = fwc19_m[3::12]
fwc19_mon5 = fwc19_m[4::12]
fwc19_mon6 = fwc19_m[5::12]
fwc19_mon7 = fwc19_m[6::12]
fwc19_mon8 = fwc19_m[7::12]
fwc19_mon9 = fwc19_m[8::12]
fwc19_mon10 = fwc19_m[9::12]
fwc19_mon11 = fwc19_m[10::12]
fwc19_mon12 = fwc19_m[11::12]
fwc19_mon1_ts = np.nanmean(fwc19_mon1, axis=(0,1,2))
fwc19_mon2_ts = np.nanmean(fwc19_mon2, axis=(0,1,2))
fwc19_mon3_ts = np.nanmean(fwc19_mon3, axis=(0,1,2))
fwc19_mon4_ts = np.nanmean(fwc19_mon4, axis=(0,1,2))
fwc19_mon5_ts = np.nanmean(fwc19_mon5, axis=(0,1,2))
fwc19_mon6_ts = np.nanmean(fwc19_mon6, axis=(0,1,2))
fwc19_mon7_ts = np.nanmean(fwc19_mon7, axis=(0,1,2))
fwc19_mon8_ts = np.nanmean(fwc19_mon8, axis=(0,1,2))
fwc19_mon9_ts = np.nanmean(fwc19_mon9, axis=(0,1,2))
fwc19_mon10_ts = np.nanmean(fwc19_mon10, axis=(0,1,2))
fwc19_mon11_ts = np.nanmean(fwc19_mon11, axis=(0,1,2))
fwc19_mon12_ts = np.nanmean(fwc19_mon12, axis=(0,1,2))

fwc21_mon1 = fwc21_m[0::12]
fwc21_mon2 = fwc21_m[1::12]
fwc21_mon3 = fwc21_m[2::12]
fwc21_mon4 = fwc21_m[3::12]
fwc21_mon5 = fwc21_m[4::12]
fwc21_mon6 = fwc21_m[5::12]
fwc21_mon7 = fwc21_m[6::12]
fwc21_mon8 = fwc21_m[7::12]
fwc21_mon9 = fwc21_m[8::12]
fwc21_mon10 = fwc21_m[9::12]
fwc21_mon11 = fwc21_m[10::12]
fwc21_mon12 = fwc21_m[11::12]
fwc21_mon1_ts = np.nanmean(fwc21_mon1, axis=(0,1,2))
fwc21_mon2_ts = np.nanmean(fwc21_mon2, axis=(0,1,2))
fwc21_mon3_ts = np.nanmean(fwc21_mon3, axis=(0,1,2))
fwc21_mon4_ts = np.nanmean(fwc21_mon4, axis=(0,1,2))
fwc21_mon5_ts = np.nanmean(fwc21_mon5, axis=(0,1,2))
fwc21_mon6_ts = np.nanmean(fwc21_mon6, axis=(0,1,2))
fwc21_mon7_ts = np.nanmean(fwc21_mon7, axis=(0,1,2))
fwc21_mon8_ts = np.nanmean(fwc21_mon8, axis=(0,1,2))
fwc21_mon9_ts = np.nanmean(fwc21_mon9, axis=(0,1,2))
fwc21_mon10_ts = np.nanmean(fwc21_mon10, axis=(0,1,2))
fwc21_mon11_ts = np.nanmean(fwc21_mon11, axis=(0,1,2))
fwc21_mon12_ts = np.nanmean(fwc21_mon12, axis=(0,1,2))

fwc22_mon1 = fwc22_m[0::12]
fwc22_mon2 = fwc22_m[1::12]
fwc22_mon3 = fwc22_m[2::12]
fwc22_mon4 = fwc22_m[3::12]
fwc22_mon5 = fwc22_m[4::12]
fwc22_mon6 = fwc22_m[5::12]
fwc22_mon7 = fwc22_m[6::12]
fwc22_mon8 = fwc22_m[7::12]
fwc22_mon9 = fwc22_m[8::12]
fwc22_mon10 = fwc22_m[9::12]
fwc22_mon11 = fwc22_m[10::12]
fwc22_mon12 = fwc22_m[11::12]
fwc22_mon1_ts = np.nanmean(fwc22_mon1, axis=(0,1,2))
fwc22_mon2_ts = np.nanmean(fwc22_mon2, axis=(0,1,2))
fwc22_mon3_ts = np.nanmean(fwc22_mon3, axis=(0,1,2))
fwc22_mon4_ts = np.nanmean(fwc22_mon4, axis=(0,1,2))
fwc22_mon5_ts = np.nanmean(fwc22_mon5, axis=(0,1,2))
fwc22_mon6_ts = np.nanmean(fwc22_mon6, axis=(0,1,2))
fwc22_mon7_ts = np.nanmean(fwc22_mon7, axis=(0,1,2))
fwc22_mon8_ts = np.nanmean(fwc22_mon8, axis=(0,1,2))
fwc22_mon9_ts = np.nanmean(fwc22_mon9, axis=(0,1,2))
fwc22_mon10_ts = np.nanmean(fwc22_mon10, axis=(0,1,2))
fwc22_mon11_ts = np.nanmean(fwc22_mon11, axis=(0,1,2))
fwc22_mon12_ts = np.nanmean(fwc22_mon12, axis=(0,1,2))

fwc23_mon1 = fwc23_m[0::12]
fwc23_mon2 = fwc23_m[1::12]
fwc23_mon3 = fwc23_m[2::12]
fwc23_mon4 = fwc23_m[3::12]
fwc23_mon5 = fwc23_m[4::12]
fwc23_mon6 = fwc23_m[5::12]
fwc23_mon7 = fwc23_m[6::12]
fwc23_mon8 = fwc23_m[7::12]
fwc23_mon9 = fwc23_m[8::12]
fwc23_mon10 = fwc23_m[9::12]
fwc23_mon11 = fwc23_m[10::12]
fwc23_mon12 = fwc23_m[11::12]
fwc23_mon1_ts = np.nanmean(fwc23_mon1, axis=(0,1,2))
fwc23_mon2_ts = np.nanmean(fwc23_mon2, axis=(0,1,2))
fwc23_mon3_ts = np.nanmean(fwc23_mon3, axis=(0,1,2))
fwc23_mon4_ts = np.nanmean(fwc23_mon4, axis=(0,1,2))
fwc23_mon5_ts = np.nanmean(fwc23_mon5, axis=(0,1,2))
fwc23_mon6_ts = np.nanmean(fwc23_mon6, axis=(0,1,2))
fwc23_mon7_ts = np.nanmean(fwc23_mon7, axis=(0,1,2))
fwc23_mon8_ts = np.nanmean(fwc23_mon8, axis=(0,1,2))
fwc23_mon9_ts = np.nanmean(fwc23_mon9, axis=(0,1,2))
fwc23_mon10_ts = np.nanmean(fwc23_mon10, axis=(0,1,2))
fwc23_mon11_ts = np.nanmean(fwc23_mon11, axis=(0,1,2))
fwc23_mon12_ts = np.nanmean(fwc23_mon12, axis=(0,1,2))

fwc24_mon1 = fwc24_m[0::12]
fwc24_mon2 = fwc24_m[1::12]
fwc24_mon3 = fwc24_m[2::12]
fwc24_mon4 = fwc24_m[3::12]
fwc24_mon5 = fwc24_m[4::12]
fwc24_mon6 = fwc24_m[5::12]
fwc24_mon7 = fwc24_m[6::12]
fwc24_mon8 = fwc24_m[7::12]
fwc24_mon9 = fwc24_m[8::12]
fwc24_mon10 = fwc24_m[9::12]
fwc24_mon11 = fwc24_m[10::12]
fwc24_mon12 = fwc24_m[11::12]
fwc24_mon1_ts = np.nanmean(fwc24_mon1, axis=(0,1,2))
fwc24_mon2_ts = np.nanmean(fwc24_mon2, axis=(0,1,2))
fwc24_mon3_ts = np.nanmean(fwc24_mon3, axis=(0,1,2))
fwc24_mon4_ts = np.nanmean(fwc24_mon4, axis=(0,1,2))
fwc24_mon5_ts = np.nanmean(fwc24_mon5, axis=(0,1,2))
fwc24_mon6_ts = np.nanmean(fwc24_mon6, axis=(0,1,2))
fwc24_mon7_ts = np.nanmean(fwc24_mon7, axis=(0,1,2))
fwc24_mon8_ts = np.nanmean(fwc24_mon8, axis=(0,1,2))
fwc24_mon9_ts = np.nanmean(fwc24_mon9, axis=(0,1,2))
fwc24_mon10_ts = np.nanmean(fwc24_mon10, axis=(0,1,2))
fwc24_mon11_ts = np.nanmean(fwc24_mon11, axis=(0,1,2))
fwc24_mon12_ts = np.nanmean(fwc24_mon12, axis=(0,1,2))

fwc25_mon1 = fwc25_m[0::12]
fwc25_mon2 = fwc25_m[1::12]
fwc25_mon3 = fwc25_m[2::12]
fwc25_mon4 = fwc25_m[3::12]
fwc25_mon5 = fwc25_m[4::12]
fwc25_mon6 = fwc25_m[5::12]
fwc25_mon7 = fwc25_m[6::12]
fwc25_mon8 = fwc25_m[7::12]
fwc25_mon9 = fwc25_m[8::12]
fwc25_mon10 = fwc25_m[9::12]
fwc25_mon11 = fwc25_m[10::12]
fwc25_mon12 = fwc25_m[11::12]
fwc25_mon1_ts = np.nanmean(fwc25_mon1, axis=(0,1,2))
fwc25_mon2_ts = np.nanmean(fwc25_mon2, axis=(0,1,2))
fwc25_mon3_ts = np.nanmean(fwc25_mon3, axis=(0,1,2))
fwc25_mon4_ts = np.nanmean(fwc25_mon4, axis=(0,1,2))
fwc25_mon5_ts = np.nanmean(fwc25_mon5, axis=(0,1,2))
fwc25_mon6_ts = np.nanmean(fwc25_mon6, axis=(0,1,2))
fwc25_mon7_ts = np.nanmean(fwc25_mon7, axis=(0,1,2))
fwc25_mon8_ts = np.nanmean(fwc25_mon8, axis=(0,1,2))
fwc25_mon9_ts = np.nanmean(fwc25_mon9, axis=(0,1,2))
fwc25_mon10_ts = np.nanmean(fwc25_mon10, axis=(0,1,2))
fwc25_mon11_ts = np.nanmean(fwc25_mon11, axis=(0,1,2))
fwc25_mon12_ts = np.nanmean(fwc25_mon12, axis=(0,1,2))

# %%
fwc1_seasonalcycle = [fwc_mon1_ts, fwc_mon2_ts, fwc_mon3_ts, fwc_mon4_ts, fwc_mon5_ts, fwc_mon6_ts,
                     fwc_mon7_ts, fwc_mon8_ts, fwc_mon9_ts, fwc_mon10_ts, fwc_mon11_ts, fwc_mon12_ts]

fwc2_seasonalcycle = [fwc2_mon1_ts, fwc2_mon2_ts, fwc2_mon3_ts, fwc2_mon4_ts, fwc2_mon5_ts, fwc2_mon6_ts,
                     fwc2_mon7_ts, fwc2_mon8_ts, fwc2_mon9_ts, fwc2_mon10_ts, fwc2_mon11_ts, fwc2_mon12_ts]

fwc3_seasonalcycle = [fwc3_mon1_ts, fwc3_mon2_ts, fwc3_mon3_ts, fwc3_mon4_ts, fwc3_mon5_ts, fwc3_mon6_ts,
                     fwc3_mon7_ts, fwc3_mon8_ts, fwc3_mon9_ts, fwc3_mon10_ts, fwc3_mon11_ts, fwc3_mon12_ts]

fwc4_seasonalcycle = [fwc4_mon1_ts, fwc4_mon2_ts, fwc4_mon3_ts, fwc4_mon4_ts, fwc4_mon5_ts, fwc4_mon6_ts,
                     fwc4_mon7_ts, fwc4_mon8_ts, fwc4_mon9_ts, fwc4_mon10_ts, fwc4_mon11_ts, fwc4_mon12_ts]

fwc6_seasonalcycle = [fwc6_mon1_ts, fwc6_mon2_ts, fwc6_mon3_ts, fwc6_mon4_ts, fwc6_mon5_ts, fwc6_mon6_ts,
                     fwc6_mon7_ts, fwc6_mon8_ts, fwc6_mon9_ts, fwc6_mon10_ts, fwc6_mon11_ts, fwc6_mon12_ts]

fwc7_seasonalcycle = [fwc7_mon1_ts, fwc7_mon2_ts, fwc7_mon3_ts, fwc7_mon4_ts, fwc7_mon5_ts, fwc7_mon6_ts,
                     fwc7_mon7_ts, fwc7_mon8_ts, fwc7_mon9_ts, fwc7_mon10_ts, fwc7_mon11_ts, fwc7_mon12_ts]

fwc9_seasonalcycle = [fwc9_mon1_ts, fwc9_mon2_ts, fwc9_mon3_ts, fwc9_mon4_ts, fwc9_mon5_ts, fwc9_mon6_ts,
                     fwc9_mon7_ts, fwc9_mon8_ts, fwc9_mon9_ts, fwc9_mon10_ts, fwc9_mon11_ts, fwc9_mon12_ts]

fwc10_seasonalcycle = [fwc10_mon1_ts, fwc10_mon2_ts, fwc10_mon3_ts, fwc10_mon4_ts, fwc10_mon5_ts, fwc10_mon6_ts,
                     fwc10_mon7_ts, fwc10_mon8_ts, fwc10_mon9_ts, fwc10_mon10_ts, fwc10_mon11_ts, fwc10_mon12_ts]

fwc11_seasonalcycle = [fwc11_mon1_ts, fwc11_mon2_ts, fwc11_mon3_ts, fwc11_mon4_ts, fwc11_mon5_ts, fwc11_mon6_ts,
                     fwc11_mon7_ts, fwc11_mon8_ts, fwc11_mon9_ts, fwc11_mon10_ts, fwc11_mon11_ts, fwc11_mon12_ts]

fwc12_seasonalcycle = [fwc12_mon1_ts, fwc12_mon2_ts, fwc12_mon3_ts, fwc12_mon4_ts, fwc12_mon5_ts, fwc12_mon6_ts,
                     fwc12_mon7_ts, fwc12_mon8_ts, fwc12_mon9_ts, fwc12_mon10_ts, fwc12_mon11_ts, fwc12_mon12_ts]

fwc13_seasonalcycle = [fwc13_mon1_ts, fwc13_mon2_ts, fwc13_mon3_ts, fwc13_mon4_ts, fwc13_mon5_ts, fwc13_mon6_ts,
                     fwc13_mon7_ts, fwc13_mon8_ts, fwc13_mon9_ts, fwc13_mon10_ts, fwc13_mon11_ts, fwc13_mon12_ts]

fwc14_seasonalcycle = [fwc14_mon1_ts, fwc14_mon2_ts, fwc14_mon3_ts, fwc14_mon4_ts, fwc14_mon5_ts, fwc14_mon6_ts,
                     fwc14_mon7_ts, fwc14_mon8_ts, fwc14_mon9_ts, fwc14_mon10_ts, fwc14_mon11_ts, fwc14_mon12_ts]

fwc15_seasonalcycle = [fwc15_mon1_ts, fwc15_mon2_ts, fwc15_mon3_ts, fwc15_mon4_ts, fwc15_mon5_ts, fwc15_mon6_ts,
                     fwc15_mon7_ts, fwc15_mon8_ts, fwc15_mon9_ts, fwc15_mon10_ts, fwc15_mon11_ts, fwc15_mon12_ts]

fwc16_seasonalcycle = [fwc16_mon1_ts, fwc16_mon2_ts, fwc16_mon3_ts, fwc16_mon4_ts, fwc16_mon5_ts, fwc16_mon6_ts,
                     fwc16_mon7_ts, fwc16_mon8_ts, fwc16_mon9_ts, fwc16_mon10_ts, fwc16_mon11_ts, fwc16_mon12_ts]

fwc17_seasonalcycle = [fwc17_mon1_ts, fwc17_mon2_ts, fwc17_mon3_ts, fwc17_mon4_ts, fwc17_mon5_ts, fwc17_mon6_ts,
                     fwc17_mon7_ts, fwc17_mon8_ts, fwc17_mon9_ts, fwc17_mon10_ts, fwc17_mon11_ts, fwc17_mon12_ts]

fwc18_seasonalcycle = [fwc18_mon1_ts, fwc18_mon2_ts, fwc18_mon3_ts, fwc18_mon4_ts, fwc18_mon5_ts, fwc18_mon6_ts,
                     fwc18_mon7_ts, fwc18_mon8_ts, fwc18_mon9_ts, fwc18_mon10_ts, fwc18_mon11_ts, fwc18_mon12_ts]

fwc19_seasonalcycle = [fwc19_mon1_ts, fwc19_mon2_ts, fwc19_mon3_ts, fwc19_mon4_ts, fwc19_mon5_ts, fwc19_mon6_ts,
                     fwc19_mon7_ts, fwc19_mon8_ts, fwc19_mon9_ts, fwc19_mon10_ts, fwc19_mon11_ts, fwc19_mon12_ts]

fwc21_seasonalcycle = [fwc21_mon1_ts, fwc21_mon2_ts, fwc21_mon3_ts, fwc21_mon4_ts, fwc21_mon5_ts, fwc21_mon6_ts,
                     fwc21_mon7_ts, fwc21_mon8_ts, fwc21_mon9_ts, fwc21_mon10_ts, fwc21_mon11_ts, fwc21_mon12_ts]

fwc22_seasonalcycle = [fwc22_mon1_ts, fwc22_mon2_ts, fwc22_mon3_ts, fwc22_mon4_ts, fwc22_mon5_ts, fwc22_mon6_ts,
                     fwc22_mon7_ts, fwc22_mon8_ts, fwc22_mon9_ts, fwc22_mon10_ts, fwc22_mon11_ts, fwc22_mon12_ts]

fwc23_seasonalcycle = [fwc23_mon1_ts, fwc23_mon2_ts, fwc23_mon3_ts, fwc23_mon4_ts, fwc23_mon5_ts, fwc23_mon6_ts,
                     fwc23_mon7_ts, fwc23_mon8_ts, fwc23_mon9_ts, fwc23_mon10_ts, fwc23_mon11_ts, fwc23_mon12_ts]

fwc24_seasonalcycle = [fwc24_mon1_ts, fwc24_mon2_ts, fwc24_mon3_ts, fwc24_mon4_ts, fwc24_mon5_ts, fwc24_mon6_ts,
                     fwc24_mon7_ts, fwc24_mon8_ts, fwc24_mon9_ts, fwc24_mon10_ts, fwc24_mon11_ts, fwc24_mon12_ts]

fwc25_seasonalcycle = [fwc25_mon1_ts, fwc25_mon2_ts, fwc25_mon3_ts, fwc25_mon4_ts, fwc25_mon5_ts, fwc25_mon6_ts,
                     fwc25_mon7_ts, fwc25_mon8_ts, fwc25_mon9_ts, fwc25_mon10_ts, fwc25_mon11_ts, fwc25_mon12_ts]


ens_mean_cycle = [sum(x)/22 for x in zip(fwc1_seasonalcycle, fwc2_seasonalcycle, fwc3_seasonalcycle,
                 fwc4_seasonalcycle, fwc6_seasonalcycle, fwc7_seasonalcycle,
                 fwc9_seasonalcycle, fwc10_seasonalcycle, fwc11_seasonalcycle,
                 fwc12_seasonalcycle, fwc13_seasonalcycle, fwc14_seasonalcycle,
                 fwc15_seasonalcycle, fwc16_seasonalcycle, fwc17_seasonalcycle,
                 fwc18_seasonalcycle, fwc19_seasonalcycle, 
                 fwc21_seasonalcycle, fwc22_seasonalcycle, fwc23_seasonalcycle,
                 fwc24_seasonalcycle, fwc25_seasonalcycle)]

# %% [markdown]
# ---
# Ensemble Trends Calculation -- September only

# %%
fwc_mon9_9ts = np.nanmean(fwc_mon9, axis=(1,2))
fwc2_mon9_9ts = np.nanmean(fwc2_mon9, axis=(1,2))
fwc3_mon9_9ts = np.nanmean(fwc3_mon9, axis=(1,2))
fwc4_mon9_9ts = np.nanmean(fwc4_mon9, axis=(1,2))
fwc6_mon9_9ts = np.nanmean(fwc6_mon9, axis=(1,2))
fwc7_mon9_9ts = np.nanmean(fwc7_mon9, axis=(1,2))
fwc9_mon9_9ts = np.nanmean(fwc9_mon9, axis=(1,2))
fwc10_mon9_9ts = np.nanmean(fwc10_mon9, axis=(1,2))
fwc11_mon9_9ts = np.nanmean(fwc11_mon9, axis=(1,2))
fwc12_mon9_9ts = np.nanmean(fwc12_mon9, axis=(1,2))
fwc13_mon9_9ts = np.nanmean(fwc13_mon9, axis=(1,2))
fwc14_mon9_9ts = np.nanmean(fwc14_mon9, axis=(1,2))
fwc15_mon9_9ts = np.nanmean(fwc15_mon9, axis=(1,2))
fwc16_mon9_9ts = np.nanmean(fwc16_mon9, axis=(1,2))
fwc17_mon9_9ts = np.nanmean(fwc17_mon9, axis=(1,2))
fwc18_mon9_9ts = np.nanmean(fwc18_mon9, axis=(1,2))
fwc19_mon9_9ts = np.nanmean(fwc19_mon9, axis=(1,2))
fwc21_mon9_9ts = np.nanmean(fwc21_mon9, axis=(1,2))
fwc22_mon9_9ts = np.nanmean(fwc22_mon9, axis=(1,2))
fwc23_mon9_9ts = np.nanmean(fwc23_mon9, axis=(1,2))
fwc24_mon9_9ts = np.nanmean(fwc24_mon9, axis=(1,2))
fwc25_mon9_9ts = np.nanmean(fwc25_mon9, axis=(1,2))

x = (fwc_mon9_9ts,  fwc2_mon9_9ts, fwc3_mon9_9ts, fwc4_mon9_9ts, fwc6_mon9_9ts, fwc7_mon9_9ts, fwc9_mon9_9ts, 
    fwc10_mon9_9ts, fwc11_mon9_9ts, fwc12_mon9_9ts, fwc13_mon9_9ts, fwc14_mon9_9ts, fwc15_mon9_9ts, fwc16_mon9_9ts,
     fwc17_mon9_9ts, fwc18_mon9_9ts, fwc19_mon9_9ts, fwc21_mon9_9ts, fwc22_mon9_9ts,
     fwc23_mon9_9ts, fwc24_mon9_9ts, fwc25_mon9_9ts)

# %%
ensmean = np.average([fwc_mon9_9ts, fwc2_mon9_9ts, fwc3_mon9_9ts, fwc4_mon9_9ts, fwc6_mon9_9ts, fwc7_mon9_9ts,  
           fwc9_mon9_9ts, fwc10_mon9_9ts, fwc11_mon9_9ts, fwc12_mon9_9ts, fwc13_mon9_9ts, fwc14_mon9_9ts, 
            fwc15_mon9_9ts, fwc16_mon9_9ts, fwc17_mon9_9ts, fwc18_mon9_9ts, fwc19_mon9_9ts,  
           fwc21_mon9_9ts, fwc22_mon9_9ts, fwc23_mon9_9ts, fwc24_mon9_9ts, fwc25_mon9_9ts], axis=0)

# slowgroup = np.average([fwc10_mon9_9ts, fwc17_mon9_9ts, fwc18_mon9_9ts, fwc25_mon9_9ts], axis=0)

# fastgroup = np.average([fwc7_mon9_9ts, fwc14_mon9_9ts, fwc21_mon9_9ts], axis=0)

# %%
phc_data = Dataset('../DATA/phc3.0_annual.nc')

phc_salt = phc_data.variables['salt'][:20,-30:,:] # time, depth, lat, lon
phc_lat = phc_data.variables['lat'][-30:]
phc_lon = phc_data.variables['lon'][:]

depths = np.asarray([0, 10, 20, 30, 50, 75, 100, 125,
         150, 200, 250, 300, 400, 500, 600,
         700, 800, 900, 100, 1100, 1200, 1300, 
         1400, 1500]) # units: meters

ocn_lyr_thick = np.array([10, 10, 10, 20, 25, 25, 25, 25, 50, 50, 50, 100, 100, 100, 100, 100, 100, 100, 100, 100])
one_ary = np.ones((20,30,360), np.float32)

dz = ocn_lyr_thick[:, None, None] * one_ary #creates 3d array of thicknesses at each lat-lon grid point

# Arctic Ocean domain mask
phc_salt[:, :-24, :] = np.nan # bering
phc_salt[:, :-10, -90:] = np.nan # fbso west
phc_salt[:, :-10, :15] = np.nan # fbso east
phc_salt[:, -30:-13, 180+55:360-90] = np.nan # caa

sal_ref = 34.8
phc_salt_m = np.ma.masked_where(phc_salt[:,:,:] > sal_ref, phc_salt[:,:,:])
phc_fwc = np.sum(((sal_ref - phc_salt_m) / sal_ref) * dz, axis=0) # Calculates liquid freshwater column, units m

# monthly_phc_fwc = np.nanmean(phc_fwc, axis=(0,1))

# %%
# New OBS - SODA
ncz = Dataset('../DATA/soda_lfwc_1980-2014.nc')
soda_lfwc = ncz.variables['lfwc'][:,:,:]
soda_lfwc_m = np.ma.masked_where(soda_lfwc <= 0.00000001, soda_lfwc)
soda_lfwc_ts = np.average(soda_lfwc_m, axis=0) # full 1980 - 2014 record

# %% [markdown]
# ---

# %%
fig = plt.figure(figsize=(6,6))

gs = GridSpec(4,4, left=0.05, right=0.48, wspace=0.6)

#--------------------------------------------------------------------------------------------------------------------
ax1 = fig.add_subplot(gs[:-1, :])
m = Basemap(projection='npstere', boundinglat=60, lon_0=0, resolution='c', round=True)
par = np.arange(0, 90, 5)
mer = np.arange(0, 360, 45)
x,y = np.meshgrid(phc_lon[:], phc_lat[:])
X,Y = m(x,y)
fwc_levs = np.arange(0,22,2)
m.drawcoastlines(linewidth=0.5)
m.fillcontinents('0.75')
m.drawparallels(par, dashes=(1,4))
m.drawmeridians(mer, labels=[True, True, True, True], dashes=(1,4), fontsize=8);
cs = m.contourf(X,Y, phc_fwc[:,:], fwc_levs, extend='max', cmap=cmo.cm.ice_r)

cb = plt.colorbar(cs, label='Liquid Freshwater Content [m]', pad=0.05, orientation='horizontal', shrink=0.5);
cb.ax.tick_params(labelsize=8)

lon_fs = np.linspace(-15,15) # fram strait
lat_fs = np.linspace(80,80)
lon_bso = np.linspace(15,15) # barents sea opening
lat_bso = np.linspace(68,80)
lon_ber = np.linspace(-166,-171) # bering strait
lat_ber = np.linspace(66,66)
lon_nar = np.linspace(-45-20, -45-25) # nares strait
lat_nar = np.linspace(80,80)
a,b = m(lon_fs, lat_fs)
c,d = m(lon_bso, lat_bso)
e,f = m(lon_ber, lat_ber)
g,h = m(lon_nar, lat_nar)
m.plot(a,b, linewidth=2, color='r', linestyle='--');
m.plot(c,d, linewidth=2, color='r', linestyle='--');
m.plot(e,f, linewidth=2, color='r', linestyle='--');
m.plot(g,h, linewidth=2, color='r', linestyle='--');
plt.annotate('FS', xy=(0.45,0.29), xycoords='axes fraction', color='r', fontsize=9);
plt.annotate('BSO', xy=(0.46,0.18), xycoords='axes fraction', color='r', fontsize=9);
plt.annotate('BS', xy=(0.39,0.925), xycoords='axes fraction', color='r', fontsize=9);
plt.annotate('NS', xy=(0.315,0.38), xycoords='axes fraction', color='r', fontsize=9);

plt.annotate('A', xy=(-0.2,1), xycoords='axes fraction', fontsize=9);

# ------------------------------------------------------------------------------------------------------------------
ax2 = fig.add_subplot(gs[-1, :2])
plt.plot(ens_mean_cycle, lw=1.25, color='k')
plt.xticks(ticks=np.arange(0,12,1), labels=['J', 'F', 'M', 'A', 'M', 'J', 'J', 'A', 'S', 'O', 'N', 'D'], fontsize=8);
plt.yticks(ticks=np.arange(9.2,10.4,0.2), labels=['9.2', ' ', '9.6', ' ', '10.0', ' '], fontsize=8);
plt.ylim([9.2,10.2]);
plt.xlim([0,11]);
plt.yticks(fontsize=8);
plt.ylabel('Mean seasonal\ncycle [m]', fontsize=8);

plt.annotate('B', xy=(0.025,0.85), xycoords='axes fraction', fontsize=9);

# ------------------------------------------------------------------------------------------------------------------
ax3 = fig.add_subplot(gs[-1, -2:])
t = np.arange(1980,2015,1)
a = 0.25
ens_c = 'grey'
lw = 0.75
plt.plot(t, fwc_mon9_9ts, c=ens_c, alpha=a, lw=lw)
plt.plot(t, fwc2_mon9_9ts[:], c=ens_c, alpha=a, lw=lw)
plt.plot(t, fwc3_mon9_9ts[:], c=ens_c, alpha=a, lw=lw)
plt.plot(t, fwc4_mon9_9ts[:], c=ens_c, alpha=a, lw=lw)
plt.plot(t, fwc6_mon9_9ts[:], c=ens_c, alpha=a, lw=lw)
plt.plot(t, fwc7_mon9_9ts[:], c=ens_c, alpha=a, lw=lw)
plt.plot(t, fwc9_mon9_9ts[:], c=ens_c, alpha=a, lw=lw)
plt.plot(t, fwc10_mon9_9ts[:], c=ens_c, alpha=a, lw=lw)
plt.plot(t, fwc11_mon9_9ts[:], c=ens_c, alpha=a, lw=lw)
plt.plot(t, fwc12_mon9_9ts[:], c=ens_c, alpha=a, lw=lw)
plt.plot(t, fwc13_mon9_9ts[:], c=ens_c, alpha=a, lw=lw)
plt.plot(t, fwc14_mon9_9ts[:], c=ens_c, alpha=a, lw=lw)
plt.plot(t, fwc15_mon9_9ts[:], c=ens_c, alpha=a, lw=lw)
plt.plot(t, fwc16_mon9_9ts[:], c=ens_c, alpha=a, lw=lw)
plt.plot(t, fwc17_mon9_9ts[:], c=ens_c, alpha=a, lw=lw)
plt.plot(t, fwc18_mon9_9ts[:], c=ens_c, alpha=a, lw=lw)
plt.plot(t, fwc19_mon9_9ts[:], c=ens_c, alpha=a, lw=lw)
plt.plot(t, fwc21_mon9_9ts[:], c=ens_c, alpha=a, lw=lw)
plt.plot(t, fwc22_mon9_9ts[:], c=ens_c, alpha=a, lw=lw)
plt.plot(t, fwc23_mon9_9ts[:], c=ens_c, alpha=a, lw=lw)
plt.plot(t, fwc24_mon9_9ts[:], c=ens_c, alpha=a, lw=lw)
plt.plot(t, fwc25_mon9_9ts[:], c=ens_c, alpha=a, lw=lw, label='Indvl. member')
plt.plot(t, ensmean[-35:], c='k', lw=lw*1.25, label='Ensemble mean')

plt.ylim([6,13]);
plt.xlim([1980,2015]);
plt.ylabel('LFWC [m]', fontsize=8);
# plt.legend(loc='upper right', ncol=1, frameon=True, fontsize=6);
ax3.yaxis.set_label_position("right")
ax3.yaxis.tick_right()
plt.yticks(ticks=np.arange(6,14,1), labels=['6', ' ', '8', ' ', '10', ' ','12', ' '], fontsize=8);
plt.xticks(ticks=np.arange(1980,2014,10), labels=['1980', '1990' , '2000', '2010', ' '], fontsize=8);
plt.annotate('C', xy=(0.025,0.85), xycoords='axes fraction', fontsize=9);
plt.annotate('  Indvl. run', xy=(0.6, 0.05), xycoords='axes fraction', fontsize=6, color=ens_c);
plt.annotate('Ens. mean', xy=(0.61, 0.15), xycoords='axes fraction', fontsize=6, color='k');

# plt.savefig('../../FIGURES/Fig1_domain_seasonalcycle_trends_FINAL.png', dpi=300, bbox_inches='tight');
